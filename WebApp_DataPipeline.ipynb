# %% [markdown]
# # Web Application for Data Visualisation By Ruchika Gupta

# %% [markdown]
# ## Import data from URL

# %%
# Import library to import online dataset into the python pandas dataframe
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/resbaz/r-novice-gapminder-files/master/data/gapminder-FiveYearData.csv')

# %%
df
# Out:
#           country  year         pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# ## Load data to mongoDB

# %%
# Imports
import pandas as pd
from pymongo import MongoClient

# Load csv dataset
data = df
# Connect to MongoDB
client =  MongoClient("mongodb+srv://rugupta:rugupta@cluster0.ai0vgvc.mongodb.net/?retryWrites=true&w=majority")

# %%
db = client['countrydb']
collection = db['country']
data_dict = data.to_dict("records")
# Insert collection
collection.insert_many(data_dict)

# %%
collection.count_documents({})# number of documents
# Out:
# 1704

# %% [markdown]
# ## Fetching data from mongoDB

# %%
all_records = collection.find()
print(all_records)

# %%
list_cursor = list(all_records)
print(list_cursor)
# Out:
# [{'_id': ObjectId('64ee2ed55506b43f2c3d7312'), 'country': 'Afghanistan', 'year': 1952, 'pop': 8425333.0, 'continent': 'Asia', 'lifeExp': 28.801, 'gdpPercap': 779.4453145}, {'_id': ObjectId('64ee2ed55506b43f2c3d7313'), 'country': 'Afghanistan', 'year': 1957, 'pop': 9240934.0, 'continent': 'Asia', 'lifeExp': 30.332, 'gdpPercap': 820.8530296}, {'_id': ObjectId('64ee2ed55506b43f2c3d7314'), 'country': 'Afghanistan', 'year': 1962, 'pop': 10267083.0, 'continent': 'Asia', 'lifeExp': 31.997, 'gdpPercap': 853.10071}, {'_id': ObjectId('64ee2ed55506b43f2c3d7315'), 'country': 'Afghanistan', 'year': 1967, 'pop': 11537966.0, 'continent': 'Asia', 'lifeExp': 34.02, 'gdpPercap': 836.1971382}, {'_id': ObjectId('64ee2ed55506b43f2c3d7316'), 'country': 'Afghanistan', 'year': 1972, 'pop': 13079460.0, 'continent': 'Asia', 'lifeExp': 36.088, 'gdpPercap': 739.9811058}, {'_id': ObjectId('64ee2ed55506b43f2c3d7317'), 'country': 'Afghanistan', 'year': 1977, 'pop': 14880372.0, 'continent': 'Asia', 'lifeExp': 38.43
# ...

# %% [markdown]
# ### Converting list into tabular form

# %%
df = pd.DataFrame(list_cursor)
df
# Out:
#                            _id      country  year         pop continent  \
# 0     64ee2ed55506b43f2c3d7312  Afghanistan  1952   8425333.0      Asia
# 1     64ee2ed55506b43f2c3d7313  Afghanistan  1957   9240934.0      Asia
# 2     64ee2ed55506b43f2c3d7314  Afghanistan  1962  10267083.0      Asia
# 3     64ee2ed55506b43f2c3d7315  Afghanistan  1967  11537966.0      Asia
# 4     64ee2ed55506b43f2c3d7316  Afghanistan  1972  13079460.0      Asia
# ...                        ...          ...   ...         ...       ...
# 1699  64ee2ed55506b43f2c3d79b5     Zimbabwe  1987   9216418.0    Africa
# 1700  64ee2ed55506b43f2c3d79b6     Zimbabwe  1992  10704340.0    Africa
# 1701  64ee2ed55506b43f2c3d79b7     Zimbabwe  1997  11404948.0    Africa
# 1702  64ee2ed55506b43f2c3d79b8     Zimbabwe  2002  11926563.0    Africa
# 1703  64ee2ed55506b43f2c3d79b9     Zimbabwe  2007  12311143.0    Africa
#
#       lifeExp   gdpPercap
# 0      28.801  779.445314
# 1      30.332  820.853030
# ...

# %% [markdown]
# # Chart 1: Top 10 Countries With highest population in 2007

# %%
# filtering data into dataframe for graph analysis 
df1 = df[df['year'] == 2007]
df1=df1.sort_values(by='pop', ascending=False).head(10)
df1
# Out:
#                            _id        country  year           pop continent  \
# 299   64ee2ed55506b43f2c3d743d          China  2007  1.318683e+09      Asia
# 707   64ee2ed55506b43f2c3d75d5          India  2007  1.110396e+09      Asia
# 1619  64ee2ed55506b43f2c3d7965  United States  2007  3.011399e+08  Americas
# 719   64ee2ed55506b43f2c3d75e1      Indonesia  2007  2.235470e+08      Asia
# 179   64ee2ed55506b43f2c3d73c5         Brazil  2007  1.900106e+08  Americas
# 1175  64ee2ed55506b43f2c3d77a9       Pakistan  2007  1.692706e+08      Asia
# 107   64ee2ed55506b43f2c3d737d     Bangladesh  2007  1.504483e+08      Asia
# 1139  64ee2ed55506b43f2c3d7785        Nigeria  2007  1.350312e+08    Africa
# 803   64ee2ed55506b43f2c3d7635          Japan  2007  1.274680e+08      Asia
# 995   64ee2ed55506b43f2c3d76f5         Mexico  2007  1.087009e+08  Americas
#
#       lifeExp     gdpPercap
# 299    72.961   4959.114854
# 707    64.698   2452.210407
# 1619   78.242  42951.653090
# ...

# %% [markdown]
# # Chart 2: Top 10 Countries With highest population in 1952

# %%
# filtering data into dataframe for graph analysis 
df2 = df[df['year'] == 1952] 
df2=df2.sort_values(by='pop', ascending=False).head(10)
df2
# Out:
#                            _id         country  year           pop continent  \
# 288   64ee2ed55506b43f2c3d7432           China  1952  5.562635e+08      Asia
# 696   64ee2ed55506b43f2c3d75ca           India  1952  3.720000e+08      Asia
# 1608  64ee2ed55506b43f2c3d795a   United States  1952  1.575530e+08  Americas
# 792   64ee2ed55506b43f2c3d762a           Japan  1952  8.645902e+07      Asia
# 708   64ee2ed55506b43f2c3d75d6       Indonesia  1952  8.205200e+07      Asia
# 564   64ee2ed55506b43f2c3d7546         Germany  1952  6.914595e+07    Europe
# 168   64ee2ed55506b43f2c3d73ba          Brazil  1952  5.660256e+07  Americas
# 1596  64ee2ed55506b43f2c3d794e  United Kingdom  1952  5.043000e+07    Europe
# 768   64ee2ed55506b43f2c3d7612           Italy  1952  4.766600e+07    Europe
# 96    64ee2ed55506b43f2c3d7372      Bangladesh  1952  4.688686e+07      Asia
#
#       lifeExp     gdpPercap
# 288    44.000    400.448611
# 696    37.373    546.565749
# 1608   68.440  13990.482080
# ...

# %% [markdown]
# ## Chart 3: Top 5 Countries With Highest Life Expectancy in 1952

# %%
# filtering data into dataframe for graph analysis 
df3 = df[df['year'] == 1952]
df3=df3.sort_values(by='lifeExp', ascending=False).head(5)
df3
# Out:
#                            _id      country  year         pop continent  \
# 1140  64ee2ed55506b43f2c3d7786       Norway  1952   3327728.0    Europe
# 684   64ee2ed55506b43f2c3d75be      Iceland  1952    147962.0    Europe
# 1080  64ee2ed55506b43f2c3d774a  Netherlands  1952  10381988.0    Europe
# 1464  64ee2ed55506b43f2c3d78ca       Sweden  1952   7124673.0    Europe
# 408   64ee2ed55506b43f2c3d74aa      Denmark  1952   4334000.0    Europe
#
#       lifeExp     gdpPercap
# 1140    72.67  10095.421720
# 684     72.49   7267.688428
# 1080    72.13   8941.571858
# 1464    71.86   8527.844662
# 408     70.78   9692.385245

# %% [markdown]
# ## Chart 4: Top 5 Countries With Highest Life Expectancy in 2007

# %%
# filtering data into dataframe for graph analysis 
df4 = df[df['year'] == 2007]
df4=df4.sort_values(by='lifeExp', ascending=False).head(5)
df4
# Out:
#                            _id          country  year          pop continent  \
# 803   64ee2ed55506b43f2c3d7635            Japan  2007  127467972.0      Asia
# 671   64ee2ed55506b43f2c3d75b1  Hong Kong China  2007    6980412.0      Asia
# 695   64ee2ed55506b43f2c3d75c9          Iceland  2007     301931.0    Europe
# 1487  64ee2ed55506b43f2c3d78e1      Switzerland  2007    7554661.0    Europe
# 71    64ee2ed55506b43f2c3d7359        Australia  2007   20434176.0   Oceania
#
#       lifeExp    gdpPercap
# 803    82.603  31656.06806
# 671    82.208  39724.97867
# 695    81.757  36180.78919
# 1487   81.701  37506.41907
# 71     81.235  34435.36744

# %% [markdown]
# ## Chart 5: GDP Percap of Selected Countries between Years 1952 to 2007

# %%
# filtering data into dataframe for graph analysis 
df5 = df[(df['country'] == 'India')|(df['country'] == 'United States')|(df['country'] == 'Canada')|(df['country'] == 'Japan')|(df['country'] == 'China')|(df['country'] == 'United Kingdom')]
df5
# Out:
#                            _id        country  year          pop continent  \
# 240   64ee2ed55506b43f2c3d7402         Canada  1952   14785584.0  Americas
# 241   64ee2ed55506b43f2c3d7403         Canada  1957   17010154.0  Americas
# 242   64ee2ed55506b43f2c3d7404         Canada  1962   18985849.0  Americas
# 243   64ee2ed55506b43f2c3d7405         Canada  1967   20819767.0  Americas
# 244   64ee2ed55506b43f2c3d7406         Canada  1972   22284500.0  Americas
# ...                        ...            ...   ...          ...       ...
# 1615  64ee2ed55506b43f2c3d7961  United States  1987  242803533.0  Americas
# 1616  64ee2ed55506b43f2c3d7962  United States  1992  256894189.0  Americas
# 1617  64ee2ed55506b43f2c3d7963  United States  1997  272911760.0  Americas
# 1618  64ee2ed55506b43f2c3d7964  United States  2002  287675526.0  Americas
# 1619  64ee2ed55506b43f2c3d7965  United States  2007  301139947.0  Americas
#
#       lifeExp    gdpPercap
# 240    68.750  11367.16112
# ...

# %% [markdown]
# ## Chart 6: Life Expectancy in Selected Countries between Years 1952 to 2007

# %%
# filtering data into dataframe for graph analysis 
df6 = df[(df['country'] == 'China')|(df['country'] == 'India')|(df['country'] == 'United Kingdom')|(df['country'] == 'Canada')|(df['country'] == 'United States')|(df['country'] == 'Japan')]
df6
# Out:
#                            _id        country  year          pop continent  \
# 240   64ee2ed55506b43f2c3d7402         Canada  1952   14785584.0  Americas
# 241   64ee2ed55506b43f2c3d7403         Canada  1957   17010154.0  Americas
# 242   64ee2ed55506b43f2c3d7404         Canada  1962   18985849.0  Americas
# 243   64ee2ed55506b43f2c3d7405         Canada  1967   20819767.0  Americas
# 244   64ee2ed55506b43f2c3d7406         Canada  1972   22284500.0  Americas
# ...                        ...            ...   ...          ...       ...
# 1615  64ee2ed55506b43f2c3d7961  United States  1987  242803533.0  Americas
# 1616  64ee2ed55506b43f2c3d7962  United States  1992  256894189.0  Americas
# 1617  64ee2ed55506b43f2c3d7963  United States  1997  272911760.0  Americas
# 1618  64ee2ed55506b43f2c3d7964  United States  2002  287675526.0  Americas
# 1619  64ee2ed55506b43f2c3d7965  United States  2007  301139947.0  Americas
#
#       lifeExp    gdpPercap
# 240    68.750  11367.16112
# ...

# %% [markdown]
# ### Installing plotly for generating graphs. It is using javascript to build interactive graphs

# %%
# !pip install plotly==5.4.0

# %% [markdown]
# # FLASK API to display charts on Web App

# %%
from flask import Flask, render_template
import pandas as pd
import json
import plotly
import plotly.express as px

app = Flask(__name__)

@app.route('/')
def index():
    return render_template('index.html')

@app.route('/chart1')
def chart1():
    # Bar Chart displaying Top 10 Countries With highest population in 2007.
    fig = px.bar(df1, x='country', y='pop', color='country',title='Top 10 Countries With Highest Population in 2007')

    graphJSON = json.dumps(fig, cls=plotly.utils.PlotlyJSONEncoder)
    return render_template('graphs.html', graphJSON=graphJSON)

@app.route('/chart2')
def chart2():
    # Bar Chart displaying Top 10 Countries With highest population in 1952.
    fig = px.bar(df2, x='country', y='pop', color='country',title='Top 10 Countries With Highest Population in 1952')

    graphJSON = json.dumps(fig, cls=plotly.utils.PlotlyJSONEncoder)
    return render_template('graphs.html', graphJSON=graphJSON)

@app.route('/chart3')
def chart3():
    # Scatter Chart displaying Top 5 Countries With Highest Life Expectancy in 1952.
    fig = px.scatter(df3, x="country", y="lifeExp", color='country', size='lifeExp',title='Top 5 Countries With Highest Life Expectancy in 1952')

    graphJSON = json.dumps(fig, cls=plotly.utils.PlotlyJSONEncoder)
    return render_template('graphs.html', graphJSON=graphJSON)

@app.route('/chart4')
def chart4():
    # Scatter Chart displaying Top 5 Countries With Highest Life Expectancy in 2007.
    fig = px.scatter(df4, x="country", y="lifeExp", color='country', size='lifeExp',title='Top 5 Countries With Highest Life Expectancy in 2007')

    graphJSON = json.dumps(fig, cls=plotly.utils.PlotlyJSONEncoder)
    return render_template('graphs.html', graphJSON=graphJSON)

@app.route('/chart5')
def chart5():
    # Line Chart displaying GDP Percap of Selected Countries between Years 1952 to 2007.
    fig = px.line(df5, x="year", y="gdpPercap", color='country',title='GDP Percap of Selected Countries between Years 1952 to 2007')

    graphJSON = json.dumps(fig, cls=plotly.utils.PlotlyJSONEncoder)
    return render_template('graphs.html', graphJSON=graphJSON)


@app.route('/chart6')
def chart6():
    # Line Chart displaying Life Expectancy in Selected Countries between Years 1952 to 2007.
    fig = px.line(df6, x="year", y="lifeExp", color='country',title='Life Expectancy in Selected Countries between Years 1952 to 2007')

    graphJSON = json.dumps(fig, cls=plotly.utils.PlotlyJSONEncoder)
    return render_template('graphs.html', graphJSON=graphJSON)

if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [29/Aug/2023 13:47:00] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Aug/2023 13:47:00] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Aug/2023 13:47:18] "GET /chart1 HTTP/1.1" 200 -

# %% [markdown]
# # Performing all activities every 24 hours (fetching data from MongoDB and updating charts on Flask API)

# %%
import time

while True:
    import time
    import sqlite3
    from flask import Flask, render_template
    import pandas as pd
    import json
    import plotly
    import plotly.express as px
    from pymongo import MongoClient
    
    client =  MongoClient("mongodb+srv://rugupta:rugupta@cluster0.ai0vgvc.mongodb.net/?retryWrites=true&w=majority")
    db = client['countrydb']
    collection = db['country']
    all_records = collection.find()
    list_cursor = list(all_records)
    df = pd.DataFrame(list_cursor)
    
    
    app = Flask(__name__)

    @app.route('/')
    def index():
        return render_template('index.html')

    @app.route('/chart1')
    def chart1():

        fig = px.bar(df1, x='country', y='pop', color='country',title='Top 10 Countries With Population in 2007')

        graphJSON = json.dumps(fig, cls=plotly.utils.PlotlyJSONEncoder)
        return render_template('graphs.html', graphJSON=graphJSON)

    @app.route('/chart2')
    def chart2():

        fig = px.bar(df2, x='country', y='pop', color='country',title='Top 10 Countries With Population in 1952')

        graphJSON = json.dumps(fig, cls=plotly.utils.PlotlyJSONEncoder)
        return render_template('graphs.html', graphJSON=graphJSON)

    @app.route('/chart3')
    def chart3():

        fig = px.scatter(df3, x="country", y="lifeExp", color='country', size='lifeExp',title='Top 5 Countries With Highest Life Expectancy in 1952')

        graphJSON = json.dumps(fig, cls=plotly.utils.PlotlyJSONEncoder)
        return render_template('graphs.html', graphJSON=graphJSON)

    @app.route('/chart4')
    def chart4():

        fig = px.scatter(df4, x="country", y="lifeExp", color='country', size='lifeExp',title='Top 5 Countries With Highest Life Expectancy in 2007')

        graphJSON = json.dumps(fig, cls=plotly.utils.PlotlyJSONEncoder)
        return render_template('graphs.html', graphJSON=graphJSON)

    @app.route('/chart5')
    def chart5():

        fig = px.line(df5, x="year", y="gdpPercap", color='country',title='GDP Percap of Selected Countries between Years 1952 to 2007')

        graphJSON = json.dumps(fig, cls=plotly.utils.PlotlyJSONEncoder)
        return render_template('graphs.html', graphJSON=graphJSON)


    @app.route('/chart6')
    def chart6():

        fig = px.line(df6, x="year", y="lifeExp", color='country',title='Life Expectancy in Selected Countries between Years 1952 to 2007')

        graphJSON = json.dumps(fig, cls=plotly.utils.PlotlyJSONEncoder)
        return render_template('graphs.html', graphJSON=graphJSON)

    if __name__ == "__main__":
        app.run()
  



    time.sleep(86400) # 86400 Seconds mean 24 Hours of time. So this code will run every 24 hours and build new graphs
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
